# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukta2002/Python/blob/main/Kalyan_jwlrs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter Name: ")
gender=input("Enter Gender: ")
age=int(input("Enter Age: "))
print("\nOUR PRODUCTS: \n",
"1)Ring \n",
"2)Chain \n",
"3)Earring \n")
pname=input("Enter product name:")
pweight=float(input("Enter product gram:"))
gram=4815
z=gram*pweight
print(pname,"price(in Rs.):",z)
print("Making charges(%)= 8")
pamount=(z+(8*z)/100)
print("Purchase amount of",pname,"is:",pamount)
D1=20
D2=30
D3=40
D4=15
D5=25
D6=35
D7=45
print("-------------------------- \n")
print("INVOICE \n")
print("YOUR NAME :",name)
print("YOUR AGE :",age)
print("PRODUCT NAME :",pname)
print("PURCHASE AMOUNT :",pamount)

if gender=="Male":
    if age>65:
        if 100000<pamount<200000:
            print("DISCOUNT(%) :",D1)
            print("DISCOUNT AMOUNT:",(D1*pamount/100))
            NM=pamount-(D1*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
        elif 200000<pamount<300000:
            print("DISCOUNT(%) :",D2)
            print("DISCOUNT AMOUNT:",(D2*pamount/100))
            NM=pamount-(D2*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
        elif 300000<pamount<400000:
            print("DISCOUNT(%) :",D3) 
            print("DISCOUNT AMOUNT:",(D3*pamount/100)) 
            NM=pamount-(D3*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))

    
    else:
        if 100000<pamount<200000:
            print("DISCOUNT(%) :",D4)
            print("DISCOUNT AMOUNT:",(D4*pamount/100))
            NM=pamount-(D4*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
        elif 200000<pamount<300000:
            print("DISCOUNT(%) :",D5)
            print("DISCOUNT AMOUNT:",(D5*pamount/100))
            NM=pamount-(D5*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
        elif 300000<pamount<400000:
            print("DISCOUNT(%) :",D6)
            print("DISCOUNT AMOUNT:",(D6*pamount/100)) 
            NM=pamount-(D6*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100)) 


elif gender=="Female":
    if age>65:
        if 100000<pamount<200000:
            print("DISCOUNT(%) :",D5)
            print("DISCOUNT AMOUNT:",(D5*pamount/100))
            NM=pamount-(D5*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
        elif 200000<pamount<300000:
            print("DISCOUNT(%) :",D6,)
            print("DISCOUNT AMOUNT:",(D6*pamount/100))
            NM=pamount-(D6*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
        elif 300000<pamount<400000:
            print("DISCOUNT(%) :",D7)
            print("DISCOUNT AMOUNT:",(D7*pamount/100))
            NM=pamount-(D7*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))  

    
    else:
        if 100000<pamount<200000:
            print("DISCOUNT(%) :",D1)
            print("DISCOUNT AMOUNT:",(D1*pamount/100))
            NM=pamount-(D1*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
        elif 200000<pamount<300000:
            print("DISCOUNT(%) :",D2)
            print("DISCOUNT AMOUNT:",(D2*pamount/100))
            NM=pamount-(D2*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
        elif 300000<pamount<400000: 
            print("DISCOUNT(%) :",D3) 
            print("DISCOUNT AMOUNT:",(D3*pamount/100))
            NM=pamount-(D3*pamount/100)
            G=3
            print("-----------------")
            print("NET AMOUNT:",NM+(NM*G/100))
# Out:
# Enter Name: Mukta
# Enter Gender: Female
# Enter Age: 18
#
# OUR PRODUCTS:
#  1)Ring
#  2)Chain
#  3)Earring
#
# Enter product name:Earring
# Enter product gram:21
# Earring price(in Rs.): 101115.0
# Making charges(%)= 8
# Purchase amount of Earring is: 109204.2
#
#  -------------------------
#
# INVOICE
#
# YOUR NAME : Mukta
# YOUR AGE : 18
# PRODUCT NAME : Earring
# PURCHASE AMOUNT : 109204.2
# DISCOUNT(%) : 20
# DISCOUNT AMOUNT: 21840.84
# -----------------
# NET AMOUNT: 89984.2608
